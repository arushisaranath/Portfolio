# %% [markdown]
# # Assignment 1

# %% [markdown]
# The first assignment was a report on the U.N. World Happiness Data. A country's happinesss level was based on a lot of features like GDP per capita, social support, Healthy Life Expectancy, Freedom to make life choices, Generosity, Perceptions of curruption and terrorist attacks. Country's were put into five categories depending on their level of happiness- 1= Very Low, 2= Low, 3= Average, 4= High, 5= Very High.

# %% [markdown]
# I then went on to visualize the relationship between the level of happiness and some other variables.
#
# The first case being social support. As one would expect,social support and happiness levels were positively correlated. With an increase in social support, it was observed that happiness levels moved from 1-5 that is from very low to very high.
#
# Next I visualized the relationship between happiness levels and GDP per capita. Again, we could see that GDP per capita and happiness levels were positively correlated and that with an increase in GDP per capita, happiness levels moved from 1-5, from very low to very high.
#
# Following this, I visualized the relationship between the level of happiness and generosity and observed that Generosity and happiness levels were not very correlated. It could be seen that an increase in generosity almsot equally made people happy or less happy/(unhappy).
#
# Next, I visualized the relationship between the level of happiness and the freedom to make life choices. According to the visualization, we could see that Freedom to make life choices and happiness levels were positively correlated. With an increase in Freedom, happiness levels moved from 1-5, very low to very high. This shift was gradual.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After this, I went on to check feature importance based on which features would help predict happiness levels using models. I learned that GDP per capita was an important relevant predictor of happiness followed by healthy life expectancy. Logicaly speaking, this add up. One of the base conditions for being happy is having enough resources to live well which is ensured by a high GDP per capita. A healthy life expectancy and social support naturally make one happier, whcih are the next important features for prediction.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After understanding feature importance, I went on to run different type of models. I ran a Random Forest Classifier with n estimators as 300 and max depth as 3. It had an accuracy of 44.12%, an F1 score of	39.34%, precision of 51.06%	and recall of 46.71%.
#
# Following this, I ran a Random Forest Classifier with n estimators as 100 and max depth as 5. It had an accuracy of 44.12%, an F1 score of	41.39%, precision of 	50.67%	and recall of 46.71% .
#
# The next model I ran was a Random Forest Classifier with n estimators as 100 and max depth as 6. It had an accuracy of 50.00%, an F1 score of	48.72%, precision of 	59.38%	and recall of 52.43%.
#
# After this, I used Grid search cv to determine best parameters and then submit models with those parameters. I used this for Random FOrest Classifier and Gradient Boosting Classifier. I learned that 300 n estimators was a good number for both Random FOrest and Gradient Boosting Classifiers. I also ran two sequential models with 3 and 4 hidden layers.
#
# The best models out of the many I tried before and after discussion with my team were the Model using Random Forest Classifier using n_estimators as 300 and max_depth as 7, the Gradient Boosting Classifier using n_estimators as 300 and max_depth as 7, both correctly predicted by GridSearchCV and the Sequential Model with 128,64,64,32,5 neurons in the layers.
#
# I tried using different values of n_estimators and max_depths(3,5,6,7) in the Random Forest and Gradient Boosting Models (100,300,400) and experimented with a sequential model with more hidden layers. The Random Forest Model with n estimators as 100 and max depth as 5 also performed well.
#
#  My best model had an accuracy score of 52.94%, an f1 score of 51.25 %, precision of 65.11% and recall 55.29%. It was a Random Forest Classifier with n estimators as 300 and max_depth as 7. It was 33rd on the leaderboard.
#
# The model that performed best according to the leaderboard was a Random Forest Classifier with an accuracy of 55.88%, an f-1 score of	53.97%, precision of	78.98% and recall of 59.29%. A lot of models that performed well were Gradient Boosting Classifiers too. It depends a lot on the paramters used in these models.

# %% [markdown]
# # Assignment 2

# %% [markdown]
# The second assignment was to write up a report on findings from Covid Positive X-Ray image data.
#
# The Dataset contains 3487 Chest X-ray images, which include 423 COVID-19, 1485 viral pneumonia, and 1579 normal X-ray images. If we can develop a predictive model using this dataset, we can use the model to determine if a person has covid/ pneumonia depending on the images. If a model can be trained to recognize when a person has covid or pneumonia, when new data is used in the model, it can predict if the x-ray image resembles a covid, pneumonia or normal image. This is very beneficial for doctors, patients and people in the healthcare industry as more people can be diagnosed and it reduces the load on doctors to go through every single X-ray. Results are obtained faster and treatment can begin almost immediately for a lot of people. A model sorting through several images in a small span of time is very helpful as multiple people's results can be obtained rapidly and reliably.
#
# First, I  visualized images that showed when x-rays demonstrate Covid Positivity, when they demonstrated pneumonia and when they were normal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The training and testing datasets are now classified as 1s and 0s based on appropriate coumns of covid, pneumonia or normal.
#
# Next, I began building prediction models.
# The first was a sequential model with an input Conv2D layer of shape 192,192,3, kernel size=3, 32 filters and relu activation followed by another Conv2D layer, kernel size=1, 32 filters and relu activation followed by MaxPooling. The same pattern was repeated 4 more times with the filter size increasing to 32, then 64, then 128, then 512 and 512 again. In the end, it is flattened and classified into 3 categories using the softmax activation. The model is compiled with the adam optimizer. It runs for 1 epoch, The accuracy for this model is 33.31%, the f-1 score is 16.66% and the precision is 11.10%.
#
# Following this, I built an Inception V3 Model.
# The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. The weights used are unfrozen imagenet weights. It is fitted to run for 1 epoch. Another GAP layer and output layer are added. The accuracy for this model is 31.76%, the f-1 score is 26.55% and the precision is 29.33%.
#
# Next I built a vgg 16 model
# This model has 1 hidden layer consisting of 112 neurons. The weights fitten to the model are imagenet weights. It runs for one epoch. The accuracy for this model is 33.31%, the f-1 score is 16.55% and the precision is 11.10%. Its learning rate is 0.01.
#
# The best model out of the ones I had tried here before discussion with my team was Model 2 which was a transfer learning model - Inception V3.
#
# The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 1 epoch. Another GAP layer and output layer were added. The accuracy for this model was 31.76%, the f-1 score was 26.55% and the precision was 29.33%.

# %% [markdown]
# My fourth model was a ResNet50 model and the model had one GAP layer and output layer added to the frozen layers of the original model. It was fit to run for 1 epoch. The accuracy for this model is 33.31%, the f-1 score is 16.66% and the precision is 11.10%.
#
# My Next model was an Inception V3 model. It had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 5 epochs. Another GAP layer and output layer were added. It was fitted again to run for 5 epochs. The accuracy for this model is 28.43 %, the f-1 score is 21.17% and the precision is 28.44%.
#
# My sixth model was a Vgg 16model with 2 dense layers with 112 neurons each for 1 epoch. The accuracy for this model is 13.38%, the f-1 score is 16.69% and the precision is 11.13%. Its learning rate is 0.01

# %% [markdown]
# Following this, I augmented the data, tried to plot the augmented images, put it together and ran another Inception V3 model. (Transfer learning)
# The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 1 epoch. Another GAP layer and output layer were added. It was then fitted to run for 5 epochs and it used the adam optimizer to compile the model. The accuracy for this model is 131.22, the f-1 score is 27.63% and the precision is 30.23%.

# %% [markdown]
# The best models out of the many I tried before and after discussion with my team were the following models:
#
# 1) Model 2 which was a transfer learning model - Inception V3.
#
# The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 1 epoch. Another GAP layer and output layer were added. The accuracy for this model is 31.76%, the f-1 score is 26.55% and the precision is 29.33%.
#
# 2) Model 5 which was a transfer learning model- Inception V3.
#
# The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 5 epochs. Another GAP layer and output layer were added. It was fitted again to run for 5 epochs. The accuracy for this model was 28.43 %, the f-1 score was 21.17% and the precision was 28.44%.
#
# 3) Model 6 is slightly better than the rest of the other models but very marginally despite running for 5 epochs. It was however a vgg 16 model with 2 dense layers with 112 neurons in each.The accuracy for this model was 13.38%, the f-1 score was 16.69% and the precision was 11.13%. Its learning rate was 0.01
#
# 4) The last model after data augmentation was the best.It was a transfer learning model - Inception V3. The model had one GAP layer and output layer added to the frozen layers of the original model , 311 layers in base model, 301 layers frozen in base model. It was fitted to run for 1 epoch. Another GAP layer and output layer were added. It was then fitted to run for 5 epochs.The accuracy for this model was 31.22%, the f-1 score was 27.63% and the precision was 30.23%.
#
# I tried using the sequential model(Model 1), the RestNet Model (Model 4) and the vgg 16 model with one dense layer and 112 neurons but their results were not great.
#
# The best models on the leaderboard however, were keras sequential models, with 1-3 dense layers and adam optimizer for compilation

# %% [markdown]
# # Assignment 3

# %% [markdown]
# The dataset has positive and negative labels assigned to sentences extracted from movie reviews based on the sentiment/ words/ language of the sentences/reviews. The data is split into training and testing datasets,X_train, X_test, y train, ytest to develop the model.
#
# A predictive model will automatically segregate positive and negative movie reviews using sentiment analysis. It is faster and more efficient which saves time and money.
#
# Once the model learns when reviews\ classify as positive or negative, it reduces a lot of work for organisations that primarily work in the film industry like give movie scores eg. rotten tomatoes. If they know whether a movie has more positive or negative reviews, it becomes easier to score them and leave a final review.

# %% [markdown]
# To train models so that they could predict positive and negative sentences from reviews better, I built the next 6 models. Based on their performance, we can understand which ones predict the best.
#
# Model 1:
# My first model had 5 LSTM layers with 32 neurons each, a batch size=32, and a validation split = 0.2. I ran it for 1 epoch and used the optimiser rmsprop. It had an accuracy of 50.82%, an f-1 score of 35.23%, precision of 75.19% and recall of 50.88%
#
# MODEL 2:
# This model had an embedded layer and conv 1 D layers. It had 2 layers with 64 neurons, 2 layers with 32 neurons followed by Max pooling,then 2 layers with16 neurons in each followed by Global average pooling. It uses the optimizer rmsprop, has a batch size =32 and validation split = 0.2. This model had an accuracy of 49.95%, an f-1 score of 33.31%, precision of 24.97% and recall of 50.00%
#
# Model 3:
#  My best model before discussion- I used transfer learning with glove embeddings. I applied these weights on the conv 1 d model which had 2 layers of 64 neurons, 2 layers of 32 neurons and eventually 2 layers of 16 neurons. I ran 10 epochs, had a batch_size=32,validation_split=0.01, optimizer='rmsprop' and had an accuracy of 79.69%, an f-1 score of79.66%,, precision of 79.89% and recall of 79.70%
#
# Model 4:
#  My best model overall- It had 5 lstm layers,each layer had 32 neurons. I ran it for 20 epochs, it had a batch size of 32, validation split of 0.001 and used the optimizer rmsprop to compile.This model had the highest scores and best results. It had an accuracy of 81.01%, an f-1 score of 80.98%, precision of 81.24% and recall of 81.01%. However, after using best parameters to build the model, we had an accuracy of 65.20%, an f-1 score of 63.21%, precision of 69.47% and recall of 65.23%
#
# Model 5: This model is similar to the other transfer learning model- model3. Since that was my best model before discussion, I wanted to incorporate some changes to see how much better it could be. I increased the batch size from 32 to 64 and ran it for 20 epochs. It is a transfer learning model with glove embeddings and is applied to the same conv 1 d model(model 2) as model 3. This however reduces the model's perfromance with an accuracy score of 77.61%, an f-1 score of 77.58%, precision of 77.73% and recall of 77.60%
#
# Model 6: Since my previous LSTM model (Model 4) was my best model, I wanted to change a few aspects about the model and check if it was still as good. I changed the dropout from 0.2 to none. I added two more LSTM layers, ran it for 20 epochs, with a batch size of 64 and a validation split og 0.001. Surprisingly, it underperformed and had an accuracy score of75.41%, f-1 score of 75.41%, precision of 75.42% and recall of 75.41%.

# %% [markdown]
# Most of the models that performed well were like mine keras sequential models. They had varied number of LSTM layers, one of the models had 8 conv1 d layers, everybody modified their models depending on what they believed to be most efficient and on the basis of the best paramters. The two main optimisers that had been used for compilation were Adam and Rmsprop with rmsprop being used more frequently.

# %% [markdown]
# # Github Links

# %% [markdown]
# HW 1: https://github.com/arushisaranath/World-Happiness-Report
#
# HW 2: https://github.com/arushisaranath/X-ray-image-detection
#
# HW 3: https://github.com/arushisaranath/Movie-Review-Sentiment-Analysis-Model
#
# HW 4: https://github.com/arushisaranath/Portfolio/tree/main/notebook
